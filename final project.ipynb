# %%
# !pip install nasdaq-data-link
import nasdaqdatalink
nasdaqdatalink.ApiConfig.api_key = '5BwoEH6x8VTcx9HS8hca'
nasdaqdatalink.get_table('QUOTEMEDIA/PRICES',date='2017-10-31,2017-10-30,2017-10-27', ticker='XOM,WMT,VZ')
data = nasdaqdatalink.get("FRED/GDP", start_date="2001-12-31", end_date="2005-12-31")
print(data)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 5
#     data = nasdaqdatalink.get("XOM", start_date="2001-12-31", end_date="2005-12-31")
#
#   File ~\AppData\Roaming\Python\Python39\site-packages\nasdaqdatalink\get.py:48 in get
#     data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#
#   File ~\AppData\Roaming\Python\Python39\site-packages\nasdaqdatalink\model\dataset.py:28 in __init__
#     raise SyntaxError(Message.ERROR_INVALID_DATABASE_CODE_FORMAT)
#
#   File <string>
# ...

# %%
nasdaqdatalink.get_table('SHARADAR/SFP', ticker=['AADR','BAB'])
# Out:
#      ticker       date   open   high     low   close    volume  closeadj  \
# None
# 0       BAB 2018-12-31  29.56  29.69  29.560  29.690  146858.0    24.951
# 1       BAB 2018-12-28  29.45  29.59  29.430  29.530  184412.0    24.817
# 2       BAB 2018-12-27  29.59  29.60  29.459  29.460  114475.0    24.758
# 3       BAB 2018-12-26  29.57  29.63  29.460  29.480  267053.0    24.775
# 4       BAB 2018-12-24  29.61  29.64  29.550  29.625  100011.0    24.896
# ...     ...        ...    ...    ...     ...     ...       ...       ...
# 159    AADR 2018-09-10  50.16  50.16  49.660  49.720   27576.0    46.744
# 160    AADR 2018-09-07  49.63  50.37  49.630  50.130   23959.0    47.129
# 161    AADR 2018-09-06  50.25  50.46  49.730  50.010   56391.0    47.017
# 162    AADR 2018-09-05  51.41  51.41  50.250  50.350   76289.0    47.336
# 163    AADR 2018-09-04  51.85  51.85  51.329  51.590   72602.0    48.502
#
#       closeunadj lastupdated
# None
# 0         29.690  2024-03-19
# ...

# %%
# Out:
#   Cell In[16], line 1
#     nasdaqdatalink.get_table('SHARADAR/SFP', date={'gte':'2017-10-01','lte':'2017-11-03'} paginate=True)
#                                                                                           ^
# SyntaxError: invalid syntax

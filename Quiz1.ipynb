# %%
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
birthmonth = "June"
for month in months:
    if birthmonth == month:
        print (month), " is my birthmonth"
# Out:
# June

# %% [markdown]
# n![comp sci hw 1.png](attachment:a72120c8-c5f6-4cec-be74-cd898aa96e6b.png)

# %%
# The csci_1070 is a repo as well as Gavin_Compsci_1070, while week_01 and week_02 are folders.
